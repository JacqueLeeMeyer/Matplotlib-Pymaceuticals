# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# Capomulin and Ramicane had smaller final tumor volumes than Infubinol and Ceftamin. In order to know for sure if this is a decrease in tumor volume, we would need to compare the final tumor volumes with beginning tumor volumes.
#
# Mouse y793 was treated with Capomulin and saw a decrease in the volume of its tumor. The decrease was approximately 12 cubic millimeters over 40 days.
#
# There is a positive correlation between mouse weight and average tumor size in the mice treated with Capomulin. As the weight of the mouse increases, so too does the average tumor volume.
#
# The male-to-female ratio in the study was nearly even.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_df=pd.merge(study_results, mouse_metadata, how='left', on='Mouse ID')

# Display the data table for preview
mouse_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
len(mouse_df['Mouse ID'].unique())
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicates = mouse_df[mouse_df.duplicated(['Mouse ID', 'Timepoint'], keep=False)]
dup_IDs=duplicates['Mouse ID'].unique()
dup_IDs
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicates = mouse_df[mouse_df.duplicated(['Mouse ID', 'Timepoint'], keep=False)]
duplicates
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_df=mouse_df.drop(mouse_df.loc[mouse_df['Mouse ID']=='g989'].index)
mouse_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
len(mouse_df['Mouse ID'].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
drug_group=mouse_df.groupby(['Drug Regimen'])
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
TV_mean=drug_group['Tumor Volume (mm3)'].mean()
TV_median=drug_group['Tumor Volume (mm3)'].median()
TV_var=drug_group['Tumor Volume (mm3)'].var()
TV_sd=drug_group['Tumor Volume (mm3)'].std()
TV_sem=drug_group['Tumor Volume (mm3)'].sem()
# Assemble the resulting series into a single summary DataFrame.
drug_stats=pd.merge(TV_mean, TV_median, on='Drug Regimen')
drug_stats.rename(columns={drug_stats.columns[0]:'Mean Tumor Volume',drug_stats.columns[1]:'Median Tumor Volume'}, inplace=True)
drug_stats=pd.merge(drug_stats, TV_var, on='Drug Regimen')
drug_stats.rename(columns={drug_stats.columns[2]:'Tumor Volume Varience'}, inplace=True)
drug_stats=pd.merge(drug_stats,TV_sd, on='Drug Regimen')
drug_stats.rename(columns={drug_stats.columns[3]:'Tumor Volume Std. Dev.'}, inplace=True)
drug_stats=pd.merge(drug_stats,TV_sem, on='Drug Regimen')
drug_stats.rename(columns={drug_stats.columns[4]:'Tumor Volume Std. Err.'}, inplace=True)
drug_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Varience  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
drug_advStats=drug_group.agg({'Tumor Volume (mm3)':['mean', 'median', 'var', 'std', 'sem']})
drug_advStats
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
# drugs = mouse_df['Drug Regimen'].unique()
Timepoint_data=mouse_df['Drug Regimen'].value_counts()
bar_graph=Timepoint_data.plot(kind='bar',
                              title = 'Total number of Mouse Timepoints by Drug Regimen',
                              xlabel='Drug Regimen',
                              ylabel='of Observed Mouse Timepoints')
xticklabels=Timepoint_data.index
bar_graph.set_xticklabels(xticklabels, rotation=90)
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
y_axis = drug_group['Drug Regimen'].value_counts()
x_axis = np.arange(0, len(y_axis.index))
tick_loc = [x for x in x_axis]
plt.figure(figsize=(6,5))
plt.ylabel('# of Observed Mouse Timepoints')
plt.xlabel('Drug Regimen')
plt.title('Total number of Mouse Timepoints by Drug Regimen')
plt.bar(x_axis, y_axis, align='center')
plt.xticks(tick_loc, y_axis.index, rotation='vertical')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_group=mouse_df.groupby('Sex')
count=gender_group['Mouse ID'].unique()
Female=len(count['Female'])
Male=len(count['Male'])
gender_count=pd.DataFrame({'Sex':['Female','Male'],
                           'Count':[Female,Male]})
gender_count=gender_count.set_index('Sex')
gender_pie=gender_count.plot(kind='pie', y='Count',autopct='%1.1f%%')
gender_pie.set_ylabel('Sex')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_group=mouse_df.groupby('Sex')
count=gender_group['Mouse ID'].unique()
Female=len(count['Female'])
Male=len(count['Male'])
gender_count=pd.DataFrame({'Sex':['Female','Male'],
                           'Count':[Female,Male]})
labels=(gender_count['Sex'])
plt.pie(gender_count['Count'],autopct='%1.1f%%', labels=labels)
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
final4=['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
mouse_df_final4=mouse_df[mouse_df['Drug Regimen'].isin(final4)]

# Start by getting the last (greatest) timepoint for each mouse
mouse_ID_group=mouse_df_final4.groupby('Mouse ID')
last_timepoint=mouse_ID_group['Timepoint'].max()
last_timepoint_df=pd.DataFrame(last_timepoint)

# # Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
Final_TumorVolume_df=pd.merge(mouse_df, last_timepoint_df, on=['Mouse ID', 'Timepoint'], how='right')
Final_TumorVolume_df=Final_TumorVolume_df[['Mouse ID', 'Drug Regimen', 'Tumor Volume (mm3)']]
Final_TumorVolume_df.reset_index(drop=True, inplace=True)
Final_TumorVolume_df.head()
# Out:
#   Mouse ID Drug Regimen  Tumor Volume (mm3)
# 0     a203    Infubinol           67.973419
# 1     a251    Infubinol           65.525743
# 2     a275     Ceftamin           62.999356
# 3     a411     Ramicane           38.407618
# 4     a444     Ramicane           43.047543

# %%
# Put treatments into a list for for loop (and later for plot labels)
final4=['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
Cap_Tumor_Vol=[]

# Calculate the IQR and quantitatively determine if there are any potential outliers.
    # Locate the rows which contain mice on each drug and get the tumor volumes
for drug in final4:
    volume=Final_TumorVolume_df.loc[Final_TumorVolume_df['Drug Regimen']==drug]
    # add subset 
    Cap_Tumor_Vol.append(volume['Tumor Volume (mm3)'])

    # Determine outliers using upper and lower bounds    
for drug in final4:
    tumor_volume=Cap_Tumor_Vol[final4.index(drug)]
    quartiles = tumor_volume.quantile([0.25, 0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    IQR = upperq-lowerq
    
    lower_bound = lowerq - (1.5*IQR)
    upper_bound = upperq + (1.5*IQR)
    
    outliers = tumor_volume[(tumor_volume < lower_bound) | (tumor_volume > upper_bound)]
    
    print(f"{drug} Potential Outliers: {outliers}")
# Out:
# Capomulin Potential Outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane Potential Outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol Potential Outliers: 15    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin Potential Outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
fig,ax=plt.subplots()
ax.boxplot(Cap_Tumor_Vol, 0,'rs')
ax.set_ylabel('Final Tumor Volume (mm3)')
ax.set_xticklabels(final4)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin (y793)
y793=mouse_df.loc[mouse_df['Mouse ID']=='y793']
x_axis=y793['Timepoint']
y_axis=y793['Tumor Volume (mm3)']
plt.xlabel('Timepoint (Days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Capomulin Treatment of Mouse y793')
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
Capomulin=mouse_df.loc[mouse_df['Drug Regimen']=='Capomulin']
Mouse_group=Capomulin.groupby('Mouse ID')
average=Mouse_group['Tumor Volume (mm3)'].mean()
Capomulin=pd.merge(Capomulin, average, on='Mouse ID')
x_axis=Capomulin['Weight (g)']
y_axis=Capomulin['Tumor Volume (mm3)_y']
plt.scatter(x_axis, y_axis)
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
slope, intersept, r, p, std_err=st.linregress(x_axis, y_axis)
fit=slope*x_axis+intersept
plt.scatter(x_axis, y_axis)
plt.plot(x_axis, fit, '--', color='red')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()
